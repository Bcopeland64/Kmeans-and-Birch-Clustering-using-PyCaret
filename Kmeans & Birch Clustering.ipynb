# %%
# !pip install pycaret --quiet
from pycaret.datasets import get_data

# %%
dataset = get_data('mice')
# Out:
#   MouseID  DYRK1A_N   ITSN1_N    BDNF_N  ...  Genotype  Treatment  Behavior   class
# 0   309_1  0.503644  0.747193  0.430175  ...   Control  Memantine       C/S  c-CS-m
# 1   309_2  0.514617  0.689064  0.411770  ...   Control  Memantine       C/S  c-CS-m
# 2   309_3  0.509183  0.730247  0.418309  ...   Control  Memantine       C/S  c-CS-m
# 3   309_4  0.442107  0.617076  0.358626  ...   Control  Memantine       C/S  c-CS-m
# 4   309_5  0.434940  0.617430  0.358802  ...   Control  Memantine       C/S  c-CS-m
#
# [5 rows x 82 columns]

# %%
dataset.shape
# Out:
# (1080, 82)

# %%
dataset.head()
# Out:
#   MouseID  DYRK1A_N   ITSN1_N    BDNF_N  ...  Genotype  Treatment  Behavior   class
# 0   309_1  0.503644  0.747193  0.430175  ...   Control  Memantine       C/S  c-CS-m
# 1   309_2  0.514617  0.689064  0.411770  ...   Control  Memantine       C/S  c-CS-m
# 2   309_3  0.509183  0.730247  0.418309  ...   Control  Memantine       C/S  c-CS-m
# 3   309_4  0.442107  0.617076  0.358626  ...   Control  Memantine       C/S  c-CS-m
# 4   309_5  0.434940  0.617430  0.358802  ...   Control  Memantine       C/S  c-CS-m
#
# [5 rows x 82 columns]

# %%
dataset.tail()
# Out:
#        MouseID  DYRK1A_N   ITSN1_N  ...  Treatment  Behavior   class
# 1075  J3295_11  0.254860  0.463591  ...     Saline       S/C  t-SC-s
# 1076  J3295_12  0.272198  0.474163  ...     Saline       S/C  t-SC-s
# 1077  J3295_13  0.228700  0.395179  ...     Saline       S/C  t-SC-s
# 1078  J3295_14  0.221242  0.412894  ...     Saline       S/C  t-SC-s
# 1079  J3295_15  0.302626  0.461059  ...     Saline       S/C  t-SC-s
#
# [5 rows x 82 columns]

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of        MouseID  DYRK1A_N   ITSN1_N  ...  Treatment  Behavior   class
# 0        309_1  0.503644  0.747193  ...  Memantine       C/S  c-CS-m
# 1        309_2  0.514617  0.689064  ...  Memantine       C/S  c-CS-m
# 2        309_3  0.509183  0.730247  ...  Memantine       C/S  c-CS-m
# 3        309_4  0.442107  0.617076  ...  Memantine       C/S  c-CS-m
# 4        309_5  0.434940  0.617430  ...  Memantine       C/S  c-CS-m
# ...        ...       ...       ...  ...        ...       ...     ...
# 1075  J3295_11  0.254860  0.463591  ...     Saline       S/C  t-SC-s
# 1076  J3295_12  0.272198  0.474163  ...     Saline       S/C  t-SC-s
# 1077  J3295_13  0.228700  0.395179  ...     Saline       S/C  t-SC-s
# 1078  J3295_14  0.221242  0.412894  ...     Saline       S/C  t-SC-s
# 1079  J3295_15  0.302626  0.461059  ...     Saline       S/C  t-SC-s
#
# [1080 rows x 82 columns]>

# %%
data_train = dataset.sample(frac=0.80, random_state=123)

# %%
data_train.shape
# Out:
# (864, 82)

# %%
data_train.head()
# Out:
#        MouseID  DYRK1A_N   ITSN1_N  ...  Treatment  Behavior   class
# 968     3425_9  0.274204  0.491040  ...     Saline       S/C  t-SC-s
# 209    3419_15  0.196671  0.364057  ...  Memantine       S/C  c-SC-m
# 790    3530_11  0.296479  0.541738  ...  Memantine       S/C  t-SC-m
# 1077  J3295_13  0.228700  0.395179  ...     Saline       S/C  t-SC-s
# 648     3505_4  0.814391  1.124141  ...  Memantine       C/S  t-CS-m
#
# [5 rows x 82 columns]

# %%
data_test = dataset.drop(data_train.index)

# %%
data_test.shape
# Out:
# (216, 82)

# %%
data_train.head()
# Out:
#        MouseID  DYRK1A_N   ITSN1_N  ...  Treatment  Behavior   class
# 968     3425_9  0.274204  0.491040  ...     Saline       S/C  t-SC-s
# 209    3419_15  0.196671  0.364057  ...  Memantine       S/C  c-SC-m
# 790    3530_11  0.296479  0.541738  ...  Memantine       S/C  t-SC-m
# 1077  J3295_13  0.228700  0.395179  ...     Saline       S/C  t-SC-s
# 648     3505_4  0.814391  1.124141  ...  Memantine       C/S  t-CS-m
#
# [5 rows x 82 columns]

# %%
data_train.reset_index(drop=True, inplace=True)

# %%
data_train.head()
# Out:
#     MouseID  DYRK1A_N   ITSN1_N    BDNF_N  ...  Genotype  Treatment  Behavior   class
# 0    3425_9  0.274204  0.491040  0.235014  ...    Ts65Dn     Saline       S/C  t-SC-s
# 1   3419_15  0.196671  0.364057  0.272195  ...   Control  Memantine       S/C  c-SC-m
# 2   3530_11  0.296479  0.541738  0.300911  ...    Ts65Dn  Memantine       S/C  t-SC-m
# 3  J3295_13  0.228700  0.395179  0.234118  ...    Ts65Dn     Saline       S/C  t-SC-s
# 4    3505_4  0.814391  1.124141  0.388574  ...    Ts65Dn  Memantine       C/S  t-CS-m
#
# [5 rows x 82 columns]

# %%
data_test.reset_index(drop=True, inplace=True)

# %%
data_test.head()
# Out:
#   MouseID  DYRK1A_N   ITSN1_N    BDNF_N  ...  Genotype  Treatment  Behavior   class
# 0   309_3  0.509183  0.730247  0.418309  ...   Control  Memantine       C/S  c-CS-m
# 1   309_4  0.442107  0.617076  0.358626  ...   Control  Memantine       C/S  c-CS-m
# 2   309_9  0.386311  0.538428  0.317720  ...   Control  Memantine       C/S  c-CS-m
# 3  309_11  0.366511  0.513278  0.327792  ...   Control  Memantine       C/S  c-CS-m
# 4  309_15  0.374410  0.462313  0.344629  ...   Control  Memantine       C/S  c-CS-m
#
# [5 rows x 82 columns]

# %%
from pycaret.clustering import *

# %%
#ignore_feature holds out the label you want to predict
clust = setup(data=data_train, normalize=True, ignore_features=['MouseID'],
              session_id=123)
# Out:
#                                Description                 Value
# 0                               session_id                   123
# 1                            Original Data             (864, 82)
# 2                           Missing Values                  True
# 3                         Numeric Features                    77
# 4                     Categorical Features                     4
# 5                         Ordinal Features                 False
# 6                High Cardinality Features                 False
# 7                  High Cardinality Method                  None
# 8                         Transformed Data             (864, 91)
# 9                                 CPU Jobs                    -1
# 10                                 Use GPU                 False
# 11                          Log Experiment                 False
# 12                         Experiment Name  cluster-default-name
# ...

# %%
kmeans = create_model('kmeans')
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0        0.12           114.3801  ...           0             0
#
# [1 rows x 6 columns]

# %%
print(kmeans)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=-1, precompute_distances='deprecated',
#        random_state=123, tol=0.0001, verbose=0)

# %%
kmodes = create_model("kmodes", num_clusters=6)
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0      0.0271            40.0634  ...           0             0
#
# [1 rows x 6 columns]

# %%
print(kmodes)
# Out:
# KModes(cat_dissim=<function matching_dissim at 0x7f9614bc40e0>, init='Cao',
#        max_iter=100, n_clusters=6, n_init=1, n_jobs=-1, random_state=123,
#        verbose=0)

# %%
models()
# Out:
#                                        Name                                          Reference
# ID
# kmeans                   K-Means Clustering                     sklearn.cluster._kmeans.KMeans
# ap                     Affinity Propagation  sklearn.cluster._affinity_propagation.Affinity...
# meanshift             Mean Shift Clustering              sklearn.cluster._mean_shift.MeanShift
# sc                      Spectral Clustering       sklearn.cluster._spectral.SpectralClustering
# hclust             Agglomerative Clustering  sklearn.cluster._agglomerative.AgglomerativeCl...
# dbscan     Density-Based Spatial Clustering                     sklearn.cluster._dbscan.DBSCAN
# optics                    OPTICS Clustering                     sklearn.cluster._optics.OPTICS
# birch                      Birch Clustering                       sklearn.cluster._birch.Birch
# kmodes                   K-Modes Clustering                               kmodes.kmodes.KModes

# %%
kmeans_result = assign_model(kmeans)

# %%
kmeans_result.head()
# Out:
#     MouseID  DYRK1A_N   ITSN1_N  ...  Behavior   class    Cluster
# 0    3425_9  0.274204  0.491040  ...       S/C  t-SC-s  Cluster 0
# 1   3419_15  0.196671  0.364057  ...       S/C  c-SC-m  Cluster 3
# 2   3530_11  0.296479  0.541738  ...       S/C  t-SC-m  Cluster 3
# 3  J3295_13  0.228700  0.395179  ...       S/C  t-SC-s  Cluster 0
# 4    3505_4  0.814391  1.124141  ...       C/S  t-CS-m  Cluster 1
#
# [5 rows x 83 columns]

# %%
#PCA Plot to more easily plot and visualize larger datasets
plot_model(kmeans)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b65161c1-511d-4496-927f-4a3733924003" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b65161c1-511d-4496-927f-4a3733924003")) {
#                     Plotly.newPlot(
#                         'b65161c1-511d-4496-927f-4a3733924003',
# ...

# %%
#Elbow plots allow us to find the optimal number of clusters (5 as is shown below)
plot_model(kmeans, plot='elbow')

# %%
#Silhouette scores allow for the evaluation of of our clustering algorithm
plot_model(kmeans, plot='silhouette')

# %%
#Distribution plot allows us to assess the the distribution of a sample comparing the empirical distribution of the data with the theoretical values expected from a specified distribution
plot_model(kmeans, plot='distribution')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c8bdd78e-1033-4975-a955-e4b3915cf117" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c8bdd78e-1033-4975-a955-e4b3915cf117")) {
#                     Plotly.newPlot(
#                         'c8bdd78e-1033-4975-a955-e4b3915cf117',
# ...

# %%
plot_model(kmeans, plot='distribution', feature='class')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e04840ad-4e06-400f-9d9a-076cdc0cf907" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e04840ad-4e06-400f-9d9a-076cdc0cf907")) {
#                     Plotly.newPlot(
#                         'e04840ad-4e06-400f-9d9a-076cdc0cf907',
# ...

# %%
#Combination of TSNE plots, Elbow Plots, Silhouette, Distance, and Distribution for side-by-side comaparison
evaluate_model(kmeans)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
test_pred = predict_model(kmeans, data=data_test)

# %%
test_pred.head()
# Out:
#   MouseID  DYRK1A_N   ITSN1_N    BDNF_N  ...  Treatment  Behavior   class    Cluster
# 0   309_3  0.509183  0.730247  0.418309  ...  Memantine       C/S  c-CS-m  Cluster 2
# 1   309_4  0.442107  0.617076  0.358626  ...  Memantine       C/S  c-CS-m  Cluster 1
# 2   309_9  0.386311  0.538428  0.317720  ...  Memantine       C/S  c-CS-m  Cluster 1
# 3  309_11  0.366511  0.513278  0.327792  ...  Memantine       C/S  c-CS-m  Cluster 1
# 4  309_15  0.374410  0.462313  0.344629  ...  Memantine       C/S  c-CS-m  Cluster 0
#
# [5 rows x 83 columns]

# %%
save_model(kmeans, "kmeans_model")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True,
#                                        features_todrop=['MouseID'],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[],
#                                        target='UNSUPERVISED_DUMMY_TARGET',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='most frequent',
#                                  fill_value_categorical=None,
#                                  fill_value_numer...
#                  ('fix_perfect', 'passthrough'),
#                  ('clean_names', Clean_Colum_Names()),
# ...

# %%
saved_model = load_model('kmeans_model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
new_pred = predict_model(saved_model, data=data_test)

# %%
new_pred.head()
# Out:
#   MouseID  DYRK1A_N   ITSN1_N    BDNF_N  ...  Treatment  Behavior   class    Cluster
# 0   309_3  0.509183  0.730247  0.418309  ...  Memantine       C/S  c-CS-m  Cluster 2
# 1   309_4  0.442107  0.617076  0.358626  ...  Memantine       C/S  c-CS-m  Cluster 1
# 2   309_9  0.386311  0.538428  0.317720  ...  Memantine       C/S  c-CS-m  Cluster 1
# 3  309_11  0.366511  0.513278  0.327792  ...  Memantine       C/S  c-CS-m  Cluster 1
# 4  309_15  0.374410  0.462313  0.344629  ...  Memantine       C/S  c-CS-m  Cluster 0
#
# [5 rows x 83 columns]

# %%
#The following clustering uses the Birch Model
birch = create_model('birch')
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0       0.107            94.2878  ...           0             0
#
# [1 rows x 6 columns]

# %%
evaluate_model(birch)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
birch_results = assign_model(birch)

# %%
birch_results.head()
# Out:
#     MouseID  DYRK1A_N   ITSN1_N  ...  Behavior   class    Cluster
# 0    3425_9  0.274204  0.491040  ...       S/C  t-SC-s  Cluster 3
# 1   3419_15  0.196671  0.364057  ...       S/C  c-SC-m  Cluster 2
# 2   3530_11  0.296479  0.541738  ...       S/C  t-SC-m  Cluster 2
# 3  J3295_13  0.228700  0.395179  ...       S/C  t-SC-s  Cluster 3
# 4    3505_4  0.814391  1.124141  ...       C/S  t-CS-m  Cluster 0
#
# [5 rows x 83 columns]

# %%
test_pred_birch = predict_model(birch, data=data_test)

# %%
test_pred_birch.head()
# Out:
#   MouseID  DYRK1A_N   ITSN1_N    BDNF_N  ...  Treatment  Behavior   class    Cluster
# 0   309_3  0.509183  0.730247  0.418309  ...  Memantine       C/S  c-CS-m  Cluster 0
# 1   309_4  0.442107  0.617076  0.358626  ...  Memantine       C/S  c-CS-m  Cluster 1
# 2   309_9  0.386311  0.538428  0.317720  ...  Memantine       C/S  c-CS-m  Cluster 1
# 3  309_11  0.366511  0.513278  0.327792  ...  Memantine       C/S  c-CS-m  Cluster 1
# 4  309_15  0.374410  0.462313  0.344629  ...  Memantine       C/S  c-CS-m  Cluster 1
#
# [5 rows x 83 columns]

# %%
save_model(birch, 'Birch_Model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True,
#                                        features_todrop=['MouseID'],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[],
#                                        target='UNSUPERVISED_DUMMY_TARGET',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='most frequent',
#                                  fill_value_categorical=None,
#                                  fill_value_numer...
#                  ('rem_outliers', 'passthrough'), ('cluster_all', 'passthrough'),
#                  ('dummy', Dummify(target='UNSUPERVISED_DUMMY_TARGET')),
# ...

# %%
saved_birch_model = load_model('Birch_Model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
new_birch_pred = predict_model(saved_birch_model, data=data_test)

# %%
new_birch_pred.head()
# Out:
#   MouseID  DYRK1A_N   ITSN1_N    BDNF_N  ...  Treatment  Behavior   class    Cluster
# 0   309_3  0.509183  0.730247  0.418309  ...  Memantine       C/S  c-CS-m  Cluster 0
# 1   309_4  0.442107  0.617076  0.358626  ...  Memantine       C/S  c-CS-m  Cluster 1
# 2   309_9  0.386311  0.538428  0.317720  ...  Memantine       C/S  c-CS-m  Cluster 1
# 3  309_11  0.366511  0.513278  0.327792  ...  Memantine       C/S  c-CS-m  Cluster 1
# 4  309_15  0.374410  0.462313  0.344629  ...  Memantine       C/S  c-CS-m  Cluster 1
#
# [5 rows x 83 columns]

# %%
# !pip install pandas-profiling --quiet

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(new_pred,  title='Kmeans Clustering Report', explorative=True)

# %%
profile_2 = ProfileReport(new_birch_pred, title="Birch Clustering Report", explorative=True)

# %%
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile.to_file("Kmeans Clustering Report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # New Section

# %%
profile_2.to_notebook_iframe()

# %%
profile_2.to_file("Birch Clustering Report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
